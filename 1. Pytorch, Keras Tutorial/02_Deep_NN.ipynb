# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
input_size = 1 # 1차원 데이터 입력
output_size = 1 # 1차원 데이터 출력
num_epochs = 200
learning_rate =0.001

x_train = np.array([[3.3], [4.4], [5.5], [6.71], [6.93], [4.168], 
                    [9.779], [6.182], [7.59], [2.167], [7.042], 
                    [10.791], [5.313], [7.997], [3.1]], dtype=np.float32)

y_train = np.array([[1.7], [2.76], [2.09], [3.19], [1.694], [1.573], 
                    [3.366], [2.596], [2.53], [1.221], [2.827], 
                    [3.465], [1.65], [2.904], [1.3]], dtype=np.float32)

x_train
y_train

model = nn.Linear(input_size, output_size)

loss_function = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):#100번 학습한다... for를 100번 반복
    # numpy arrays를 torch의 Tensor로 만들어 머신에 입력해야한다.
    inputs = torch.from_numpy(x_train) # X
    targets = torch.from_numpy(y_train) # y
    
    # Forward Pass
    pred = model(inputs)
    loss = loss_function(pred, targets)
    
    # Backward and Optimization
    optimizer.zero_grad() # 기존 값을 전부 초기화하기 위해 반드시 가장 먼저 한번 추가
    loss.backward()
    optimizer.step()
    
    if(epoch+1) % 5 ==0:
        print('Epoch[{}/{}], Loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))

# %%
# 시각화 할 때는 Tensor에서 Numpy로 다시 만들어줘야한다.
predict = model(torch.from_numpy(x_train)).detach().numpy()
plt.plot(x_train, y_train, 'ro', label='Original Data')
plt.plot(x_train, predict, label='Predict Line')
plt.legend()
plt.show()

torch.save(model.state_dict(),'model.ckpt')
